# %% [markdown]
# # [Seaborn Tutorial - Intro](https://youtu.be/6GUZXDef2U0?t=0)

# %% [markdown]
# ### [Setup](https://youtu.be/6GUZXDef2U0?t=28)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### [Import Data & Datasets](https://youtu.be/6GUZXDef2U0?t=137)

# %%
print(sns.get_dataset_names())
crash_df = sns.load_dataset('car_crashes')

pd.set_option('display.expand_frame_repr', False)  # will force ALL columns to display in one row
print(crash_df.head(5))
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# ...

# %% [markdown]
# ### [Distribution Plot](https://youtu.be/6GUZXDef2U0?t=262)

# %%
sns.displot(crash_df['not_distracted'])
# sns.displot(crash_df['not_distracted'], kde = True)
# sns.displot(crash_df['not_distracted'], kde = True, bins = 25)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(crash_df['not_distracted'], kde = True)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(crash_df['not_distracted'], kde = True, bins = 22)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### [Joint Plot](https://youtu.be/6GUZXDef2U0?t=413)

# %%
sns.jointplot(data = crash_df, x='speeding', y='alcohol', kind= 'reg')

# %%
sns.jointplot(data = crash_df, x='speeding', y='alcohol', kind= 'kde', fill = True, color='red')

# %% [markdown]
# ### [Hexagon Distribution](https://youtu.be/6GUZXDef2U0?t=499)

# %%
sns.jointplot(data = crash_df, x='speeding', y='alcohol', kind= 'hex')

# %% [markdown]
# ### [KDE Plot](https://youtu.be/6GUZXDef2U0?t=516)

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ### [Pair Plot](https://youtu.be/6GUZXDef2U0?t=546)

# %%
sns.pairplot(crash_df)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips_df = sns.load_dataset('tips')

sns.pairplot(tips_df, hue = 'sex', palette= 'Blues')
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### [Rug Plot](https://youtu.be/6GUZXDef2U0?t=725)

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# ### [Styling](https://youtu.be/6GUZXDef2U0?t=785)

# %%
sns.set_style('darkgrid')   # 'white'   'darkgrid'   'whitegrid'    'dark'    'ticks'

plt.clf()           # clear
plt.rcdefaults()    # defaults


plt.figure(figsize= (16,9))

sns.set_context('paper', font_scale= 1.4)    #  'paper'     'talk'     'poster'

sns.jointplot(x = 'speeding', y = 'alcohol', data = crash_df, kind = 'reg')

sns.despine(left = False, bottom= True)   # vertical or horizontal line on axes

# %% [markdown]
# # Categorial Plots

# %% [markdown]
# ### [Styling](https://youtu.be/6GUZXDef2U0?t=785)

# %%
sns.barplot(x = 'sex', y= 'total_bill', data =tips_df ,hue = 'sex', palette= 'pastel', estimator= 'median')    #  'median'   'std'   'var'
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### [Count Plot](https://youtu.be/6GUZXDef2U0?t=1175)

# %%
sns.countplot(x = 'sex', data= tips_df, hue = 'sex', palette= 'dark')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### [Box Plot](https://youtu.be/6GUZXDef2U0?t=1241)

# %%
sns.boxplot(data=tips_df, x = 'day', y = 'total_bill', hue = 'sex')

plt.legend(loc = 0)

# %% [markdown]
# ### [Violin Plot](https://youtu.be/6GUZXDef2U0?t=1397)

# %%
sns.violinplot(data=tips_df, x = 'day', y = 'total_bill', hue = 'sex', split = True)

plt.legend(loc = 0)

# %% [markdown]
# ### [Strip Plot](https://youtu.be/6GUZXDef2U0?t=1480)

# %%
plt.figure(figsize= (8,5))

sns.stripplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'sex', jitter= True, dodge= False)
plt.legend(loc = 0)

# %% [markdown]
# ### [Swam Plot](https://youtu.be/6GUZXDef2U0?t=1607)

# %%
sns.violinplot(data = tips_df, x = 'day', y = 'total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'day')
sns.swarmplot(data = tips_df, x = 'day', y = 'total_bill', color= 'white')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### [Palettes](https://youtu.be/6GUZXDef2U0?t=28m05s)

# %%
plt.figure(figsize=(8,6))

sns.set_style('white')
sns.set_context('talk')

g=sns.stripplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'sex', palette='afmhot')

# plt.gca().set_title("CORRELATION - Male/Female Tipping by Day", fontsize=18)
g.figure.suptitle("CORRELATION - Male/Female Tipping by Day", fontsize=18, color='red', fontweight='bold', x=0.5, y=.95)

plt.legend(loc = 0)

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# #### [Heatmaps](https://youtu.be/6GUZXDef2U0?t=32m12s)

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

print(crash_df.head(5))

crash_mx = crash_df.corr(numeric_only=True)

sns.heatmap(crash_mx, annot=True, cmap='Blues')  #.set( 
    # title="CORRELATION COEFFICIENTS") 

plt.gca().set_title("CORRELATION COEFFICIENTS", fontsize=18, loc= 'center')
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  ins_losses abbrev
# 0   18.8     7.332    5.640          18.048       15.040       784.55      145.08     AL
# 1   18.1     7.421    4.525          16.290       17.014      1053.48      133.93     AK
# 2   18.6     6.510    5.208          15.624       17.856       899.47      110.35     AZ
# 3   22.4     4.032    5.824          21.056       21.280       827.34      142.39     AR
# 4   12.0     4.200    3.360          10.920       10.680       878.41      165.63     CA
# Text(0.5, 1.0, 'CORRELATION COEFFICIENTS')

# %% [markdown]
# ### CORRELATION COEFFICIENT<br>
# 0.9–1.0: Very highly correlated<br>0.7–0.9: Highly correlated<br> 0.5–0.7: Moderately correlated <br>0.3–0.5: Low correlation<br> <0.3: Little to no linear correlation<br> 0: No correlation

# %% [markdown]
# A correlation coefficient is a statistical measure that describes the strength and direction of a relationship between two variables. The most common type is the Pearson correlation coefficient, which ranges from -1 to 1.
#
# 1 indicates a perfect positive correlation: as one variable increases, the other also increases.
# -1 indicates a perfect negative correlation: as one variable increases, the other decreases.
# 0 indicates no correlation: the variables don't have any linear relationship.
# Values between -1 and 1 indicate varying degrees of correlation:
#
# Closer to 1: Strong positive correlation.
# Closer to -1: Strong negative correlation.
# Closer to 0: Weak or no linear correlation.
# For example, if you're analyzing UFO sightings and temperature, a correlation coefficient of 0.8 would suggest a strong positive relationship, meaning that higher temperatures might be associated with more UFO sightings.<br>
#
# The correlation coefficient itself is not interpreted as a percentage. However, you can think of the square of the correlation coefficient (often called the coefficient of determination, or R^2) as representing the proportion of the variance in one variable that is predictable from the other variable. If the correlation coefficient is 0.8, then R^2 = 0.64 or 64%. This means that 64% of the variability in one variable can be explained by its linear relationship with the other variable.

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
print(flights)

sns.heatmap(flights, cmap = 'Blues', linecolor='white', linewidths=1)
plt.yticks(rotation=0)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# #### [Cluster Maps](https://youtu.be/6GUZXDef2U0?t=38m30s)

# %%
# Does not work with Python 3.12.4      Does work with Python 3.11.4

iris = sns.load_dataset('iris')
print(iris.head())

species = iris.pop('species')
g =sns.clustermap(iris)

g.figure.suptitle("Iris Clustermap", fontsize=24, color='red', fontweight='bold', x=0.5, y=1.05)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Text(0.5, 1.05, 'Iris Clustermap')

# %%
sns.clustermap(flights, cmap = 'Blues', standard_scale= 1)

# %% [markdown]
# #### [Pair Grid](https://youtu.be/6GUZXDef2U0?t=42m07s)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue = 'species')
iris_g.map(plt.scatter)

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue = 'species')
iris_g.map_diag(plt.hist)
# iris_g.map(plt.scatter)
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot, fill = True)

# %%
iris = sns.load_dataset('iris')
# iris_g = sns.PairGrid(iris, hue = 'species')
# iris_g.map_diag(plt.hist)
# iris_g.map(plt.scatter)
# iris_g.map_upper(plt.scatter)
# iris_g.map_lower(sns.kdeplot, fill = True)
iris_g =sns.PairGrid(iris, hue = 'species',
                    x_vars=['sepal_length', 'sepal_width'],
                    y_vars=['petal_length', 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# #### [Facet Grid](https://youtu.be/6GUZXDef2U0?t=46m53s)

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
tips_fg.map(plt.hist, 'total_bill', bins = 8)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', hue = 'smoker', aspect= 1.3,
                        col_order=['Dinner', 'Lunch'], palette= 'Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor = 'w' )
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
kws = dict(s = 50, linewidth=.5, edgecolor = 'w')
tips_fg = sns.FacetGrid(tips_df, col = 'sex', hue = 'smoker',
                        height= 4, aspect= 1.3,
                        hue_order= ['Yes', 'No'],
                        hue_kws= dict(marker= ['^', 'v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### [Regression Plots](https://youtu.be/6GUZXDef2U0?t=54m42s)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale= 1.4)
sns.lmplot(x='total_bill', y = 'tip', hue = 'sex',
           data = tips_df, markers= ['o', '^'],
           scatter_kws={'s': 100, 'linewidths': 0.5, 'edgecolor': 'w'})
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_context('paper', font_scale= 1.4)
sns.lmplot(x='total_bill', y='tip', 
           col='sex', row='time',
           data = tips_df, height= 8, aspect=0.65)
# Out:
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\fisch\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
