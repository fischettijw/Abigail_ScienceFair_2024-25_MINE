# %% [markdown]
# <style>
#   h1, h5 {
#     margin-bottom: 0; /* Remove bottom margin */
#     padding-bottom: 0; /* Remove bottom padding */
#     line-height: 1.2;  /* Adjust line height */
#   }
#   br {
#     line-height: 1.2; Adjust line height
#   }
# </style>
#
# # [Seaborn - countplot](https://www.youtube.com/watch?v=8U5h3EJuu8M&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j)

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[diamonds.clarity.isin(['SI1', 'VS2'])]

# %%
diamonds.shape
# Out:
# (25323, 10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(x='color', data=diamonds);

# %%
diamonds.color.value_counts(sort=False)
# Out:
# color
# D    3780
# E    4896
# F    4332
# G    4323
# H    3918
# I    2593
# J    1481
# Name: count, dtype: int64

# %% [markdown]
# ### Horizontal Countplot

# %%
sns.countplot(y='color', data=diamonds);

# %% [markdown]
# ## Options

# %% [markdown]
# ### `order`

# %%
sns.countplot(x='color', data=diamonds);

# %%
sns.countplot(x='cut', data=diamonds);

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamonds.color.cat.categories
# Out:
# Index(['D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %%
diamonds.cut.cat.categories
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
color_order=['J', 'I', 'H', 'G', 'F', 'E', 'D']

sns.countplot(x='color', data=diamonds, order=color_order);

# %% [markdown]
# ### Order Ascending or Descending

# %%
diamonds.color.value_counts().index
# Out:
# CategoricalIndex(['E', 'F', 'G', 'H', 'D', 'I', 'J'], categories=['D', 'E', 'F', 'G', 'H', 'I', 'J'], ordered=False, dtype='category', name='color')

# %%
sns.countplot(x='color', data=diamonds,
              order=diamonds.color.value_counts().index[::-1]  #remove [::-1] for descending
             );

# %% [markdown]
# ### `hue`, `hue_order`

# %%
sns.countplot(x='color', data=diamonds, hue='clarity', hue_order=['SI1', 'VS2']);

# %% [markdown]
# ## Styling

# %% [markdown]
# ### `color` and `palette`

# %%
sns.countplot(x='color', data=diamonds, color='skyblue');

# %%
sns.countplot(x='color', data=diamonds, palette='twilight', hue = 'color');

# %% [markdown]
# ### Other Matplotlib Properties

# %%
sns.countplot(x='color', data=diamonds,
              lw=4, ec='black', hatch='/'
             );

# %% [markdown]
# ## Examples, Thumbnail

# %%
from matplotlib import pyplot as plt

# %%
sns.set(style='darkgrid', font_scale=1.3)
sns.countplot(x='cut', data=diamonds, color='navy', lw=3)
plt.xlabel('')
plt.ylabel('Count')


plt.tight_layout()
#plt.savefig('20countplot_image_countplotExample.png', dpi=200);

# %%
sns.set_style('white')

import pandas as pd

df = pd.DataFrame({'Animal': ['dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog'],
                   'Weight': [55, 8, 12, 25, 100, 10, 60]
                  })

# %%
df
# Out:
#   Animal  Weight
# 0    dog      55
# 1    cat       8
# 2    cat      12
# 3    dog      25
# 4    dog     100
# 5    cat      10
# 6    dog      60

# %%
plt.figure(figsize=(5, 6))

sns.countplot(x='Animal', data=df, ec='black', lw=3, palette=['darkred', '#2F8F8F'])

plt.yticks([0, 1, 2, 3, 4])
plt.ylabel('Count', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats.svg');
# Out:
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\3243562361.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Animal', data=df, ec='black', lw=3, palette=['darkred', '#2F8F8F'])

# %%
df.groupby('Animal').Weight.mean()
# Out:
# Animal
# cat    10.0
# dog    60.0
# Name: Weight, dtype: float64

# %%
plt.figure(figsize=(5, 6))

sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3, 
            palette=['darkred', '#2F8F8F'],
            ci=None
           )

plt.ylim(0, 75)
plt.ylabel('Weight', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats_bar_noCI.svg');
# Out:
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\3542285659.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3,
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\3542285659.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3,

# %%
plt.figure(figsize=(5, 6))

sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3, 
            palette=['darkred', '#2F8F8F'],
            ci=68, errcolor='black'
           )

plt.ylim(0, 75)
plt.ylabel('Weight', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats_bar_withCI.svg');
# Out:
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\2642193064.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3,
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\2642193064.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3,
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\2642193064.py:3: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'black'}` instead.
#
#   sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3,

# %% [markdown]
# ### Thumb

# %%
plt.figure(figsize=(7,4))
sns.set(style='white', font_scale=1.2)
ax = sns.countplot(x='color', data=diamonds, 
                   hue='clarity', hue_order=['SI1', 'VS2'], 
                   palette=['#2F8F8F', 'lightgray'])
ax.legend([], frameon=False)
sns.despine()

plt.xlabel('')
plt.ylabel('Count', labelpad=10)
plt.tight_layout()
#plt.savefig('21countplot_image_thumb.png', dpi=200);

# %%
# import seaborn as sns
# sns.set_style('darkgrid')
# sns.countplot(x='color', data=diamonds)
# diamonds.color.value_counts(sort=False)



# import seaborn as sns

# # Load the diamonds dataset
# diamonds = sns.load_dataset('diamonds')

# sns.set_style('darkgrid')
# sns.countplot(x='color', data=diamonds)

# # Count the occurrences of each color
# print(diamonds.color.value_counts(sort=False))



import seaborn as sns

# Load the diamonds dataset
diamonds = sns.load_dataset('diamonds')

sns.set_style('darkgrid')

# Use a palette to ensure different colors for each bar
sns.countplot(x='color', data=diamonds, palette='dark')

# Count the occurrences of each color
print(diamonds.color.value_counts(sort=False))
# Out:
# color
# D     6775
# E     9797
# F     9542
# G    11292
# H     8304
# I     5422
# J     2808
# Name: count, dtype: int64
# C:\Users\fisch\AppData\Local\Temp\ipykernel_45528\1645664058.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='color', data=diamonds, palette='dark')
